# %% [markdown]
# <a href="https://colab.research.google.com/github/RachmadAprisandhy/PCDVK/blob/main/Rachmad_Praktikum_PCDVK.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# JOBSHEET 1

# %% [markdown]
# Step 1

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
from skimage import transform
from PIL import Image

# %% [markdown]
# Step 2

# %%
#membuat list untuk menyimpan url
urls = ["https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg" , "https://picsum.photos/800/600" ,"https://picsum.photos/800/600?random=2" ]
for url in urls:
    print("Mencoba:", url)

    image = io.imread(url)

    image = cv.resize(image, (0, 0), fx=0.5, fy=0.5)

    image_2 = cv.cvtColor(image, cv.COLOR_RGB2BGR)

    final_frame = cv.hconcat((image, image_2))

    cv2_imshow(final_frame)
    print()
# Out:
# Mencoba: https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg
# <PIL.Image.Image image mode=RGB size=800x276>
# Mencoba: https://picsum.photos/800/600
# <PIL.Image.Image image mode=RGB size=800x300>
# Mencoba: https://picsum.photos/800/600?random=2
# <PIL.Image.Image image mode=RGB size=800x300>

# %% [markdown]
# Langkah 3

# %%
tinggi = image_2.shape[0]
lebar = image_2.shape[1]

print("Tinggi:", tinggi)
print("Lebar:", lebar)

cv2_imshow(image_2)
# Out:
# Tinggi: 300
# Lebar: 400
# <PIL.Image.Image image mode=RGB size=400x300>

# %% [markdown]
# Langkah 4

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

for y in range(lebar):
    image_3[int(tinggi / 2), y] = [255, 255, 255]


final_frame = cv.hconcat((image_2, image_3))

cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x300>

# %% [markdown]
# Praktikum D2

# %% [markdown]
# 1. Jelaskan, mengapa pada modul praktikum ini eksekusi kode Python dilakukan
# menggunakan Google Colab?
#
# Jawab : Pada modul praktikum ini, eksekusi kode Python dilakukan menggunakan Google Colab karena Google Colab merupakan lingkungan pemrograman berbasis cloud yang memungkinkan proses komputasi dilakukan pada server, sehingga dapat mengurangi beban kerja perangkat yang digunakan.
#
# 2. Jelaskan mengenai kegunaan setiap library pada praktikum langkah ke
# delapan? Apakah semua library tersebut harus digunakan dalam praktikum
# sesi ini?
#
# jawab :
#  a. skimage
#     Digunakan untuk membaca dan menampilkan citra. Pada praktikum ini, io.imread() digunakan untuk membaca citra dari URL dan mengubahnya menjadi array yang dapat diproses oleh Python
#   b. cv2 / OpenCV
#     Digunakan untuk melakukan pengolahan citra. Dalam kode praktikum, OpenCV digunakan untuk mengubah ukuran citra dengan cv.resize(), mengubah format kanal warna dengan cv.cvtColor(), serta menggabungkan dua citra menggunakan cv.hconcat(). OpenCV memang merupakan library yang umum digunakan untuk pemrosesan dan analisis citra.
#   c. google.colab.patches (cv2_imshow)
#     Digunakan untuk menampilkan citra pada Google Colab. Fungsi cv2_imshow() menjadi alternatif cv.imshow() yang lebih sesuai digunakan pada lingkungan Google Colab.
#
# 3. Pada uji coba langkah ke-9 terdapat potongan kode program sebagai berikut :
# image = cv.resize(image, (0, 0), fx=0.5, fy=0.5)
# Apa kegunaan kode program tersebut?dan apa pengaruhnya jika tidak
# dilakukan?
# jawab : Kode tersebut digunakan untuk mengubah ukuran (resize) citra menjadi 50% dari ukuran aslinya. Parameter fx=0.5 menentukan skala perubahan pada arah horizontal, sedangkan fy=0.5 menentukan skala perubahan pada arah vertikal. Dengan demikian, tinggi dan lebar citra masing-masing menjadi setengah dari ukuran sebelumnya.
#
# 4.
